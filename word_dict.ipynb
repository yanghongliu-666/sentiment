# %% [markdown]
# # 新冠疫情初始关键词

# %%
cov_dic = [
  '新冠',
  '病毒',
  '发烧',
  'virus',
  '封村',
  '发烧',
  '输液',
  '病重',
  '流感',
  '咳嗽',
  '浑身无力',
  '急诊',
  '急诊室',
  '病例',
  '口罩',
  'SARS',
  '武汉',
  '肺炎',
  '医护人员',
  '病毒',
  '隔离',
  '瘟疫',
  '新型冠状病毒',
  '新冠病毒',
  '封城',
  '非典',
  '潜伏期',
  '传染',
  '飞沫传播',
  '粉末传播',
  '粪口传播',
  '头昏脑胀',
  '疫情',
  '禁令',
  '停课',
  '新型肺炎',
  '确诊',
  '病例',
  '潜伏期',
  '检疫',
  '非典',
  '接触史',
  '检测',
  '蝙蝠',
  '传染',
  '野味',
  '就诊',
  '发热门诊',
  '消毒',
  '红十字',
  '旅居史',
  '发病急',
  '传播',
  '体温异常',
  '钟南山',
  '火神山',
  '雷神山',
  '护士',
  '医生',
  '延长假期',
  '降低风险',
  '拐点',
  '病死率',
  '核酸检测',
  '治愈率',
  '医务人员',
  '医疗队',
  '援鄂',
  '医疗护理',
  '一线',
  '方舱医院',
  '重症隔离病房',
  '国家卫建委',
  '防护服',
  '2019-nCoV病毒',
  '白衣天使',
  '勤洗手',
  '人流密集',
  '治愈率',
  '病情',
  '抗体',
  '血浆',
  'COVID-19',
  '武汉肺炎',
  '瘟疫',
  '防护',
  '临床试验',
  '粪便',
  '死亡率',
  '病房',
  '医疗资源',
  '负重前行',
  '无私奉献',
  '同舟共济',
  '众志成城',
  '消毒',
  '清洁',
  '集中',
  '同行人员',
  '疫情防控',
  '康复',
  '韩红',
  '基金',
  '捐助',
  '驰援',
  'N-95',
  '护理',
  '溯源'
]

# %% [markdown]
# # 初始正向情感词

# %%
posi_dict = [
  '快乐',
  '浪',
  '尊敬',
  '勇敢',
  '支持',
  '爱你',
  '泪目',
  '值得',
  '平安',
  '希望',
  '健康',
  '幸福',
  '顺利',
  '发光',
  '最美',
  '贴心',
  '致敬',
  '仁慈',
  '医者仁心',
  '保重',
  '加油',
  '正能量',
  '英雄',
  '胜利',
  '回家',
  '配合',
  '心愿',
  '好起来',
  '保佑',
  '团圆',
  '负重前行',
  '奋斗',
  '凯旋',
  '无私奉献',
  '同舟共济',
  '众志成城',
  '点赞',
  '踏实',
  '正气',
  '感人',
  '好吃',
  '保重',
  '挺过难关',
  '信仰',
  '康复',
  '靠谱',
  '感恩',
  '至深',
  '棒',
  '乖',
]

# %% [markdown]
# # 初始负向情感词

# %%
nati_dict = [
  '火冒三丈',
  '怒火中烧',
  '痛苦',
  '痛恨',
  '恐惧',
  '寒心',
  '心神不定',
  '心有余悸',
  '人心惶惶',
  '惊魂未定',
  '如坐针毡',
  '惊心动魄',
  '惊恐',
  '胆怯',
  '害怕',
  '心慌',
  '畏缩',
  '惊吓悲哀',
  '痛不欲生',
  '苦涩',
  '哀伤',
  '心酸',
  '忧愁',
  '忧虑',
  '悲痛',
  '沉痛着急',
  '坐立不安',
  '心乱如麻',
  '心急如焚',
  '心事重重',
  '心烦意乱',
  '焦虑喜爱',
  '入迷',
  '心醉',
  '倾慕',
  '喜欢怨恨',
  '仇恨',
  '敌视',
  '反感',
  '可恶',
  '可恨',
  '痛恨',
  '厌恶',
  '烦闷',
  '恼苦',
  '别扭',
  '不快',
  '不爽',
  '心烦',
  '厌烦',
  '烦闷',
  '难受',
  '窝囊',
  '讨厌',
  '憋闷',
  '担心',
  '发愁',
  '愁闷'
]

# %% [markdown]
# # 较弱副词词典

# %%
fuci_dict_1 = [
  '不'
  '非'
  '没'
  '没有'
  '不用'
  '甭'
  '必'
  '必须'
  '必定 '
  '一直'
  '才'
  '也'
  '都'
  '全部'
  '总体'
  '总共'
  '共'
  '又'
  '仅仅'
  '只'
  '光'
  '一概'
  '难道'
  '决'
  '岂'
  '反正'
  '也许'
  '大约'
  '大概'
  '果然'
  '居然'
  '竟然'
  '究竟'
]

# %% [markdown]
# # 较强副词词典

# %%
fuci_dict_2 = [
  '很',
  '非常',
  '极其',
  '非常',
  '绝对',
  '极度',
  '十分',
  '最',
  '顶级',
  '太',
  '更',
  '极其',
  '格外',
  '分外'
]
